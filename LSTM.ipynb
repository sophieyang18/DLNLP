# %%
import os

def read_txt_files_with_different_encodings(folder_path):
    # 定义常见的编码方式
    encodings = ['utf-8-sig', 'gb18030', 'gbk', 'big5', 'latin1', 'iso-8859-1']
    
    # 初始化存储文件内容和文件名的列表
    file_contents = []
    file_names = []
    
    # 遍历指定文件夹中的所有文件
    for filename in os.listdir(folder_path):
        if filename.endswith(".txt"):
            file_path = os.path.join(folder_path, filename)
            # 尝试不同的编码方式读取文件
            for encoding in encodings:
                try:
                    with open(file_path, 'rb') as file:
                        content = file.read().decode(encoding)
                    # 如果成功读取，则存储内容并跳出循环
                    file_contents.append(content)
                    file_names.append(filename[:-4])  # 去掉.txt后缀
                    break
                except UnicodeDecodeError:
                    continue
            else:
                # 如果所有编码方式都失败，打印错误信息
                print(f"无法解码文件: {filename}")
    
    return file_contents, file_names

# 示例使用
folder_path = r'C:\Users\ASUS\Desktop\研一（下）\dlnlp\第三次大作业\jyxstxtqj_downcc.com'
contents, names = read_txt_files_with_different_encodings(folder_path)

for items in contents:
    print("文件内容:", items[:500])
print("文件标题:", names)
# Out:
# 文件内容: 本书来自www.cr173.com免费txt小说下载站
# 更多更新免费电子书请关注www.cr173.com
# 　　三十三剑客图
# 　　旧小说有插图和绣像，是我国向来的传统。我很喜欢读旧小说，也喜欢小说中的插图。可惜一般插图的美术水准，与小说的文学水准差得实在太远。这些插图都是木版画，是雕刻在木版上再印出来的，往往画得既粗俗，刻得又简陋，只有极少数的例外。我国版画有很悠久的历史。最古的版画作品，是汉代的肖形印，在印章上刻了龙虎禽鸟等等图印，印在绢上纸上，成为精美巧丽的图形。版画成长于隋唐时的佛画，盛于宋元，到明末而登峰造极，最大的艺术家是陈洪绶（老莲）。清代版画普遍发展，年画盛行于民间。咸丰年间的任渭长，一般认为是我国传统版画最后的一位大师。以后的版画受到西方美术的影响，和我国传统的风格是颇为不同了。我手边有一部任渭长画的版画集《卅三剑客图》，共有三十三个剑客的图形，人物的造型十分生动。偶有空闲，翻阅数页，很触发一些想象，常常引起一个念头：“最好能给每一幅图‘插’一篇短篇小说。”惯例总是画家替小说家绘插图，古今中外，似乎从未有一个写小说的人替一系列的绘画插写小说。由于读书不多，这三十三
# 文件内容: 本书来自www.cr173.com免费txt小说下载站
# 更多更新免费电子书请关注www.cr173.com
#
# 　　金庸《书剑恩仇录》
# 　　第一回　  古道腾驹惊白发    危峦快剑识青翎
# 　　清乾隆十八年六月，陕西扶风延绥镇总兵衙门内院，一个十四岁的女孩儿跳跳蹦蹦的走向教书先生书房。上午老师讲完了《资治通鉴》上“赤壁之战”的一段书，随口讲了些诸葛亮、周瑜的故事。午后本来没功课，那女孩儿却兴犹未尽，要老师再讲三国故事。这日炎阳盛暑，四下里静悄悄地，更没一丝凉风。那女孩儿来到书房之外，怕老师午睡未醒，进去不便，于是轻手轻脚绕到窗外，拔下头上金钗，在窗纸上刺了个小孔，凑眼过去张望。只见老师盘膝坐在椅上，脸露微笑，右手向空中微微一扬，轻轻吧的一声，好似甚么东西在板壁上一碰。她向声音来处望去，只见对面板壁上伏着几十只苍蝇，一动不动，她十分奇怪，凝神注视，却见每只苍蝇背上都插着一根细如头发的金针。这针极细，隔了这样远原是难以辨认，只因时交未刻，日光微斜，射进窗户，金针在阳光下生出了反光。
# 　　书房中苍蝇仍是嗡嗡的飞来飞去，老师手一扬，吧的一声，又是一只苍蝇给钉上了板壁。那女孩儿觉得
# 文件内容: 本书来自www.cr173.com免费txt小说下载站
# 更多更新免费电子书请关注www.cr173.com
#
# 　　侠客行
# 　　金庸
# 　　一      玄铁令
# 　　“赵客缦胡缨，吴钩霜雪明。银鞍照白马，疯沓如流星。
# 　　十步杀一人，千里不留行。事了拂衣去，深藏身与名。
# 　　闲过信陵饮，脱剑膝前横。将炙啖朱亥，持觞劝侯嬴。
# 　　三杯吐然诺，五岳倒为轻。眼花耳热后，意气素霓生。
# 　　救赵挥金锤，邯郸先震惊。千秋二壮士，［火亘］赫大梁城。
# 　　纵死侠骨香，不惭世上英。谁能书阁下，白首太玄经？”
# 　　李白这一首“侠客行”古风，写的是战国时魏国信陵君门客侯嬴和朱亥的故事，千载之下读来，英锐之气，兀自虎虎有威。那大梁城邻近黄河，后称汴梁，即今河南开封。该地虽然数为京城，却是民风质朴，古代悲歌慷慨的豪侠气概，后世迄未泯灭。
# 　　开封东门十二里处，有个小市镇，叫做侯监集。这小镇便因侯嬴而得名。当年侯嬴为大梁夷门监者。大梁城东有山，山势平夷，称为夷山，东城门便称为夷门。夷门监者就是大梁东门的看守小吏。
# 　　这一日已是傍晚时分，四处前来赶集的乡民正自挑担的挑担、提篮的提篮，纷
# 文件内容: 本书来自www.cr173.com免费txt小说下载站
# 更多更新免费电子书请关注www.cr173.com
#
# 　　金庸《倚天屠龙记》
# 　　一　  天涯思君不可忘
# 　　“春游浩荡，是年年寒食，梨花时节。白锦无纹香烂漫，玉树琼苞堆雪。静夜沉沉，浮光霭霭，冷浸溶溶月。人间天上，烂银霞照通彻。浑似姑射真人，天姿灵秀，意气殊高洁。万蕊参差谁信道，不与群芳同列。浩气清英，仙才卓荦，下土难分别。瑶台归去，洞天方看清绝。”
# 　　作这一首《无俗念》词的，乃南宋末年一位武学名家，有道之士。此人姓丘，名处机，道号长春子，名列全真七子之一，是全真教中出类拔萃的人物。《词品》评论此词道：“长春，世之所谓仙人也，而词之清拔如此”。这首词诵的似是梨花，其实词中真意却是赞誉一位身穿白衣的美貌少女，说她“浑似姑射真人，天姿灵秀，意气殊高洁”，又说她“浩气清英，仙才卓荦”，“不与群芳同列”。词中所颂这美女，乃古墓派传人小龙女。她一生爱穿白衣，当真如风拂玉树，雪裹琼苞，兼之生性清冷，实当得起“冷浸溶溶月”的形容，以“无俗念”三字赠之，可说十分贴切。长春子丘处机和她在终南山上比邻而居，当年一见，便写下这首词来
# 文件内容: 本书来自www.cr173.com免费txt小说下载站
# 更多更新免费电子书请关注www.cr173.com
# 　　天龙八部
# 　　一、少年游青衫磊落险峰行  玉璧月华明  马疾香幽  崖高人远  微步觳纹生谁家子弟谁家院  无计悔多情  虎啸龙吟  换巢鸾凤  剑气碧烟横
# 　　二、苏幕遮向来痴  从此醉  水榭听香 指点群豪戏  剧饮千杯男儿事  杏子林中 商略平生义昔时因  今日意  胡汉恩仇 须倾英雄泪  虽万千人吾往矣  悄立雁门 绝壁无余子
# 　　三、破阵子千里茫茫若梦 双眸粲粲如星 塞上牛羊空许约 烛畔鬓云有旧盟 莽苍踏雪行赤手屠熊搏虎 金戈荡寇鏖兵 草木残生颅铸铁 虫豸凝寒掌作冰 挥洒缚豪英
# 　　四、洞仙歌输赢成败 又争由人算  且自逍遥没谁管  奈天昏地暗 斗转星移  风骤紧 缥缈峰头云乱红颜弹指老 刹那芳华  梦里真真语真幻  同一笑 到头万事俱空胡涂醉 情长计短	解不了 名缰系嗔贪  却试问 几时把痴心断
# 　　五、水龙吟燕云十八飞骑 奔腾如虎风烟举  老魔小丑 岂堪一击 胜之不武王霸雄图 血海深仇 尽归尘土  念枉求美眷 良缘安在  枯井底 暗泥处酒罢问君三语
# 文件内容: 本书来自www.cr173.com免费txt小说下载站
# 更多更新免费电子书请关注www.cr173.com
#
# 　　射雕英雄传
# 　　金庸
# 　　第一回 风雪惊变
# 　　钱塘江浩浩江水，日日夜夜无穷无尽的从临安牛家村边绕过，东流入海。江畔一排数十株乌柏树，叶子似火烧般红，正是八月天时。村前村后的野草刚起始变黄，一抹斜阳映照之下，更增了几分萧索。两株大松树下围着一堆村民，男男女女和十几个小孩，正自聚精会神的听着一个瘦削的老者说话。
# 　　那说话人五十来岁年纪，一件青布长袍早洗得褪成了蓝灰色。只听他两片梨花木板碰了几下，右手中竹棒在一面小羯鼓上敲起得得连声。唱道：
# 　　“小桃无主自开花，烟草茫茫带晚鸦。
# 　　几处败垣围故井，向来一一是人家。”
# 　　那说话人将木板敲了几下，说道：“这首七言诗，说的是兵火过后，原来是家家户户，都变成了断墙残瓦的破败之地。小人刚才说到那叶老汉一家四口，悲欢离合，聚了又散，散了又聚。他四人给金兵冲散，好容易又再团聚，欢天喜地的回到故乡，却见房屋已给金兵烧得干干净净，无可奈何，只得去到汴梁，想觅个生计。不料想：天有不测风云，人有旦夕祸福。他四人刚进汴梁
# 文件内容: 本书来自www.cr173.com免费txt小说下载站
# 更多更新免费电子书请关注www.cr173.com
#
# 　　白马啸西风
# 　　得得得，得得得…………
# 　　得得得，得得得…………
# 　　在黄沙莽莽的回疆大漠之上，尘沙飞起两丈来高，两骑马一前一後的急
# 　　驰而来。前面是匹高腿长身的白马，马上骑著个少妇，怀中搂著个七八岁的
# 　　小姑娘。後面是匹枣红马，马背上伏著的是个高瘦的汉子。
# 　　那汉子左边背心上却插著一枝长箭。鲜血从他背心流到马背上，又流到
# 　　地下，滴入了黄沙之中。他不敢伸手拔箭，只怕这枝箭一拔下来，就会支持
# 　　不住，立时倒毙。谁不死呢？那也没什麽。可是谁来照料前面的娇妻幼女？
# 　　在身後，凶悍毒辣的敌人正在紧紧追踪。
# 　　他跨下的枣红马奔驰了数十里地，早已筋疲力尽，在主人没命价的鞭打
# 　　催踢之下，逼得气也喘不过来了，这时嘴边已全是白沫，猛地里前腿一软，
# 　　跪倒在地。那汉子用力一提缰绳，那红马一声哀嘶，抽搐了几下，便已脱力
# 　　而死。那少妇听得声响，回过头来，忽见红马倒毙，吃了一惊，叫道：「大
# 　　哥……怎……怎麽啦？」那汉子皱眉摇了摇头
# 文件内容: 本书来自www.cr173.com免费txt小说下载站
# 更多更新免费电子书请关注www.cr173.com
#
# 　　金庸《碧血剑》
# 　　第一回　  危邦行蜀道  乱世坏长城
# 　　大明成祖皇帝永乐六年八月乙未，西南海外渤泥国国王麻那惹加那乃，率同妃子、弟、妹、世子及陪臣来朝，进贡龙脑、鹤顶、玳瑁、犀角、金银宝器等诸般物事。成祖皇帝大悦，嘉劳良久，赐宴奉天门。
# 　　那孛泥国即今婆罗洲北部的婆罗乃，又称文莱（渤泥、婆罗乃、文莱以及英语Ｂｒｕｎｅｉ均系同一地名之音译），虽和中土相隔海程万里，但向来仰慕中华。宋朝太平兴国二年，其王向打（即苏丹，中国史书上译为“向打”）曾遣使来朝，进贡龙脑、象牙、檀香等物，其后朝贡不绝。
# 　　麻那惹加那乃国王眼见天朝上国民丰物阜，文治教化、衣冠器具，无不令他欢喜赞叹，明帝又相待甚厚，竟然留恋不去。到该年十一月，一来年老，二来水土不服，患病不治。成祖深为悼惜，为之辍朝三日，赐葬南京安德门外（今南京中华门外聚宝山麓，有王墓遗址，俗呼马回回坟），又命世子遐旺袭封渤泥国王，遣使者护送归国，赏赐金银、器皿、锦绮，纱罗等物。遐旺王奏称：小国后山，颇有神异，乞皇
# 文件内容: 本书来自www.cr173.com免费txt小说下载站
# 更多更新免费电子书请关注www.cr173.com
# 　　=====================================================================《神雕侠侣》目录=====================================================================
# 　　《神雕侠侣》目录
# 　　第一回 牋牋?风月无情	 第二十一回 ?襄阳鏖兵
# 　　第二回 牋牋?故人之子	 第二十二回 ?危城女婴
# 　　第三回 牋牋?求师终南	 第二十三回 ?手足情仇
# 　　第四回 牋牋?全真门下	 第二十四回 ?意乱情迷
# 　　第五回 牋牋?活死人墓	 第二十五回 ?内忧外患
# 　　第六回 牋牋?玉女心经	 第二十六回 ?神雕重剑
# 　　第七回 牋牋?重阳遗刻	 第二十七回 ?斗智斗力
# 　　第八回 牋牋?白衣少女	 第二十八回 ?洞房花烛
# 　　第九回 牋牋?百计避敌	 第二十九回 ?劫难重重
# 　　第十回 牋牋?少年英侠	 第三十回 牋?离合无常
#
# 文件内容: 本书来自www.cr173.com免费txt小说下载站
# 更多更新免费电子书请关注www.cr173.com
#
# 　　金庸《笑傲江湖》
# 　　一　  灭门
# 　　和风熏柳，花香醉人，正是南国春光漫烂季节。福建省福州府西门大街，青石板路笔直的伸展出去，直通西门。一座建构宏伟的宅第之前，左右两座石坛中各竖一根两丈来高的旗杆，杆顶飘扬青旗。右首旗上黄色丝线绣着一头张牙舞爪、神态威猛的雄狮，旗子随风招展，显得雄狮更奕奕若生。雄狮头顶有一对黑丝线绣的蝙蝠展翅飞翔。左首旗上绣着“福威镖局”四个黑字，银钩铁划，刚劲非凡。大宅朱漆大门，门上茶杯大小的铜钉闪闪发光，门顶匾额写着“福威镖局”四个金漆大字，下面横书“总号”两个小字。进门处两排长凳，分坐着八名劲装结束的汉子，个个腰板笔挺，显出一股英悍之气。
# 　　突然间后院马蹄声响，那八名汉子一齐站起，抢出大门。只见镖局西侧门中冲出五骑马来，沿着马道冲到大门之前。当先一匹马全身雪白，马勒脚镫都是烂银打就，鞍上一个锦衣少年，约莫十八九岁年纪，左肩上停着一头猎鹰，腰悬宝剑，背负长弓，泼喇喇纵马疾驰。身后跟随四骑，骑者一色青布短衣。一行五人驰到镖局门口，八名
# 文件内容: 本书来自www.cr173.com免费txt小说下载站
# 更多更新免费电子书请关注www.cr173.com
#
# 　　越    女    剑
# 　　金  庸
# 　　“请！”“请！”
# 　　两名剑士各自倒转剑尖，右手握剑柄，左手搭于右手手背，躬身行礼。
# 　　两人身子尚未站直，突然间白光闪动，跟着铮的一声响，双剑相交，两人各
# 　　退一步。旁观众人都是“咦”的一声轻呼。
# 　　青衣剑士连劈三剑，锦衫剑士一一格开。青衣剑士一声吒喝，长剑从左上角
# 　　直划而下，势劲力急。锦衫剑士身手矫捷，向后跃开，避过了这剑。他左足刚着
# 　　地，身子跟着弹起，刷刷两剑，向对手攻去。青衣剑士凝里不动，嘴角边微微冷
# 　　笑，长剑轻摆，挡开来剑。
# 　　锦衫剑士突然发足疾奔，绕着青衣剑士的溜溜的转动，脚下越来越快。青衣
# 　　剑士凝视敌手长剑剑尖，敌剑一动，便挥剑击落。锦衫剑士忽而左转，忽而右转，
# 　　身法变幻不定。青衣剑士给他转得微感晕眩，喝道：“你是比剑，还是逃命？”
# 　　刷刷两剑，直削过去。但锦衫剑士奔转甚急，剑到之时，人已离开，敌剑剑锋总
# 　　是和他身子差了尺许。
# 　　青衣剑士回剑侧身
# 文件内容:
#
# 　　连城诀
# 　　金庸
# 　　一  乡下人进城
# 　　托！托托托！托！托托！
# 　　两柄木剑挥舞交斗，相互撞击，发出托托之声。有时相隔良久而无声息，有时撞击之声密如联珠，连绵不绝。
# 　　那是在湘西沅陵南郊的麻溪乡下，三间小屋之前，晒谷场上，一对青年男女手持木剑，正在比试。
# 　　屋前矮凳上坐着一个老头儿，嘴里咬着一根短短的旱烟管，手中正在打草鞋，偶而抬起头来，向这对青年男女瞧上一眼，嘴角边微微含笑，意示嘉许。淡淡阳光穿过他口中喷出来的一缕缕青烟，照在他满头白发、满脸皱纹之上，但他向吞吐伸缩的两柄木剑瞥上一眼时，眼中神光炯然，凛凛有威，看来他的年纪其实也并不很老，似乎五十岁也还不到。
# 　　那少女十七八岁年纪，圆圆的脸蛋，一双大眼黑溜溜的，这时累得额头见汗，左颊上一条汗水流了下来，直流到颈中。她伸左手衣袖擦了擦，脸上红得象屋檐下挂着的一串串红辣椒。那青年比她大着两三岁，长脸黝黑，颧骨微高，粗手大脚，那是湘西乡下常见的庄稼少年汉子，手中一柄木剑倒使得颇为灵动。
# 　　突然间那青年手中木剑自左上方斜劈向下，跟着向后挺剑刺出，更不回头。那少女低头避过，木剑连刺，来势劲急。那青年退
# 文件内容: 本书来自www.cr173.com免费txt小说下载站
# 更多更新免费电子书请关注www.cr173.com
#
# 　　雪山飞狐
# 　　一
# 　　飕的一声，一枝羽箭从东边山坳后射了出来，呜呜声响，划过长空，穿入一头飞雁颈中。大雁带著羽箭在空中打了几个斤斗，落在雪地。
# 　　西首数十丈外，四骑马踏著皑皑白雪，奔驰正急。马上乘客听得箭声，不约而同的一齐勒马。四匹马都是身高肥膘的良驹，一受羁勒，立时止步。乘者骑术既精，牲口也都久经训练，这一勒马，显得鞍上胯下，相得益彰。四人眼见大雁中箭跌下，心中都喝一生采，要瞧那发箭的是何等样人物。
# 　　等了半晌，山坳中始终无人出来，却听得一阵马蹄声响，射箭之人竟自走了。四个乘客中一个身材瘦长、神色剽悍的老者微微皱眉，纵马奔向山坳，其馀三人跟著过去。转过山边，只见前面里许外五骑马奔驰正急，铁骑溅雪，银鬣乘风，眼见已追赶不上。那老者一摆手，说道：「殷师兄，这可有点儿邪门。」
# 　　那「殷师兄」也是个老者，身形微胖，留著两撇髭须，身披貂皮外套，气派是个富商模样，听那瘦长老者如此说，点了点头，勒马回到大雁之旁，马鞭挥出，拍的一声，抽向雪地，待得马鞭提起，鞭梢
# 文件内容:
#
# 　　飞狐外传
# 　　金庸著
# 　　第一章　大雨商家堡
# 　　“胡一刀，曲池，天枢！”
# 　　“苗人凤，地仓，合谷！”
# 　　一个嘶哑的嗓子低沉地叫着。叫声中充满着怨毒和愤怒，语声从牙齿缝中迸出来，似是千年万年、永恒的咒诅，每一个字音上涂着血和仇恨。
# 　　突突突突四声响，四道金光闪动，四枝金镖连珠发出，射向两块木牌。
# 　　每块木牌的正面反面都绘着一个全身人形，一块上绘的是个浓髯粗豪的大汉，旁注“胡一刀”三字；另一块上绘的是个瘦长汉子，旁注“苗人凤”三字，人形上书明人体周身穴道。木牌下面接有一柄，两个身手矫捷的壮汉各持一牌，在练武厅中满厅游走。
# 　　大厅东北角一张椅子中坐着一个五十来岁的白发婆婆，口中喊着胡一刀或苗人凤穴道的名称。一个二十来岁的英俊少年劲装结束，镖囊中带着十几枝金镖，听得那婆婆喊出穴道名称，右手一扬，就是一道金光射出，钉向木牌。两个持牌壮汉头戴钢丝罩子，上身穿了厚棉袄再罩牛皮背心，唯恐少年失了准头，金镖招呼到他们身上。两人窜高伏低，摇摆木牌，要让他不易打中。
# 　　大厅外的窗口，伏着一个少女、一个青年汉子。两人在窗纸上挖破了两个小孔，各用右眼凑着向里偷窥。
# 文件内容: 本书来自www.cr173.com免费txt小说下载站
# 更多更新免费电子书请关注www.cr173.com
#
# 　　四个劲装结束的汉子并肩而立，拦在当路！
# 　　若是黑道上山寨的强人，不会只有四个，莫非在这黑沈沈的松林之中，暗中还埋伏
# 　　下大批人手？如是剪径的小贼，见了这麽声势浩大的镖队，远避之唯恐不及，哪敢这般
# 　　大模大样的拦路挡道？难到竟是武林高手，冲著自己而来？
# 　　凝神打量四人：最左一人短小精悍，下巴尖削，手中拿著一对峨眉钢刺。第二个又
# 　　高又肥，便如是一座铁塔摆在地下，身前放著一块大石碑，碑上写的是「先考黄府君诚
# 　　本之墓」，这自是一块墓碑了，不知放在身前有何用意？黄诚本？没听说江湖上有这麽
# 　　一位前辈高手啊！第三个中等身材，白净脸皮，若不是一副牙齿向外突了一寸，一个鼻
# 　　头低陷了半寸，倒算是一位相貌英俊的人物，他手中拿的是一副流星锤。最右边的是个
# 　　病夫模样的中年人，衣衫褴褛，咬著一根旱烟管，双目似睁似闭，嘴里慢慢喷出烟雾，
# 　　竟是没将这一队七十来人的镖队瞧在眼里。
# 　　那三人倒还罢了，这病夫定是个内功深湛的劲敌。顷刻之间，江湖上
# 文件内容: 本书来自www.cr173.com免费txt小说下载站
# 更多更新免费电子书请关注www.cr173.com
#
# 　　鹿鼎记
# 　　第一回      纵横钩党清流祸 峭茜风期月旦评
# 　　北风如刀，满地冰霜。
# 　　江南近海滨的一条大路上，一队清兵手执刀枪，押着七辆囚车，冲风冒寒，向北而行。
# 　　前面三辆囚车中分别监禁的是三个男子，都作书生打扮，一个是白发老者，两个是中年
# 　　人。后面四辆囚车中坐的是女子，最后一辆囚车中是个少妇，怀中抱着个女婴，女婴啼哭不
# 　　休。她母亲温言相呵，女婴只是大哭。囚车旁一清兵恼了，伸腿在车上踢了一脚，喝道：“
# 　　再哭，再哭，老子踢死你!”那女婴一惊，哭得更加响了。
# 　　离开道路数十丈处有座大屋，屋檐下站着一个中年文士，一个十一二岁的小孩。那文士
# 　　见到这等情景，不禁长叹一声，眼眶也红了，说道：“可怜，可怜!”
# 　　农小孩问道：“爹爹，他们犯了什么最?”那文士道：“又犯了什么罪?昨日和今朝已逮
# 　　去了三十几人，都是我们浙江有名的读书人，个个都是无辜株连。”他说到“无辜株连”四
# 　　子，声音压得甚低，生怕给押囚车的官兵听见了。那
# 文件标题: ['三十三剑客图', '书剑恩仇录', '侠客行', '倚天屠龙记', '天龙八部', '射雕英雄传', '白马啸西风', '碧血剑', '神雕侠侣', '笑傲江湖', '越女剑', '连城诀', '雪山飞狐', '飞狐外传', '鸳鸯刀', '鹿鼎记']

# %%
lll=len(contents)
for i in range(lll):
    contents[i]=contents[i][58:]

# %%
for items in contents:
    print("文件内容:", items[0:100])
print("文件标题:", names)
novels=contents
# Out:
# 文件内容: 三十三剑客图
# 　　旧小说有插图和绣像，是我国向来的传统。我很喜欢读旧小说，也喜欢小说中的插图。可惜一般插图的美术水准，与小说的文学水准差得实在太远。这些插图都是木版画，是雕刻在木版上再印出来的，往往
# 文件内容:
# 　　金庸《书剑恩仇录》
# 　　第一回　  古道腾驹惊白发    危峦快剑识青翎
# 　　清乾隆十八年六月，陕西扶风延绥镇总兵衙门内院，一个十四岁的女孩儿跳跳蹦蹦的走向教书先生书房。上午老师讲完了《资
# 文件内容:
# 　　侠客行
# 　　金庸
# 　　一      玄铁令
# 　　“赵客缦胡缨，吴钩霜雪明。银鞍照白马，疯沓如流星。
# 　　十步杀一人，千里不留行。事了拂衣去，深藏身与名。
# 　　闲过信陵饮，脱剑膝前横。
# 文件内容:
# 　　金庸《倚天屠龙记》
# 　　一　  天涯思君不可忘
# 　　“春游浩荡，是年年寒食，梨花时节。白锦无纹香烂漫，玉树琼苞堆雪。静夜沉沉，浮光霭霭，冷浸溶溶月。人间天上，烂银霞照通彻。浑似姑射真人，天
# 文件内容: 天龙八部
# 　　一、少年游青衫磊落险峰行  玉璧月华明  马疾香幽  崖高人远  微步觳纹生谁家子弟谁家院  无计悔多情  虎啸龙吟  换巢鸾凤  剑气碧烟横
# 　　二、苏幕遮向来痴  从此醉  水榭
# 文件内容:
# 　　射雕英雄传
# 　　金庸
# 　　第一回 风雪惊变
# 　　钱塘江浩浩江水，日日夜夜无穷无尽的从临安牛家村边绕过，东流入海。江畔一排数十株乌柏树，叶子似火烧般红，正是八月天时。村前村后的野草刚起始变
# 文件内容:
# 　　白马啸西风
# 　　得得得，得得得…………
# 　　得得得，得得得…………
# 　　在黄沙莽莽的回疆大漠之上，尘沙飞起两丈来高，两骑马一前一後的急
# 　　驰而来。前面是匹高腿长身的白马，马上骑著个少
# 文件内容:
# 　　金庸《碧血剑》
# 　　第一回　  危邦行蜀道  乱世坏长城
# 　　大明成祖皇帝永乐六年八月乙未，西南海外渤泥国国王麻那惹加那乃，率同妃子、弟、妹、世子及陪臣来朝，进贡龙脑、鹤顶、玳瑁、犀角、金
# 文件内容: =====================================================================《神雕侠侣》目录=======================
# 文件内容:
# 　　金庸《笑傲江湖》
# 　　一　  灭门
# 　　和风熏柳，花香醉人，正是南国春光漫烂季节。福建省福州府西门大街，青石板路笔直的伸展出去，直通西门。一座建构宏伟的宅第之前，左右两座石坛中各竖一根两丈
# 文件内容:
# 　　越    女    剑
# 　　金  庸
# 　　“请！”“请！”
# 　　两名剑士各自倒转剑尖，右手握剑柄，左手搭于右手手背，躬身行礼。
# 　　两人身子尚未站直，突然间白光闪动，跟着铮的一声响，双
# 文件内容: 互撞击，发出托托之声。有时相隔良久而无声息，有时撞击之声密如联珠，连绵不绝。
# 　　那是在湘西沅陵南郊的麻溪乡下，三间小屋之前，晒谷场上，一对青年男女手持木剑，正在比试。
# 　　屋前矮凳上坐着一个老头
# 文件内容:
# 　　雪山飞狐
# 　　一
# 　　飕的一声，一枝羽箭从东边山坳后射了出来，呜呜声响，划过长空，穿入一头飞雁颈中。大雁带著羽箭在空中打了几个斤斗，落在雪地。
# 　　西首数十丈外，四骑马踏著皑皑白雪，奔驰
# 文件内容: 仓，合谷！”
# 　　一个嘶哑的嗓子低沉地叫着。叫声中充满着怨毒和愤怒，语声从牙齿缝中迸出来，似是千年万年、永恒的咒诅，每一个字音上涂着血和仇恨。
# 　　突突突突四声响，四道金光闪动，四枝金镖连珠发出，
# 文件内容:
# 　　四个劲装结束的汉子并肩而立，拦在当路！
# 　　若是黑道上山寨的强人，不会只有四个，莫非在这黑沈沈的松林之中，暗中还埋伏
# 　　下大批人手？如是剪径的小贼，见了这麽声势浩大的镖队，远避之唯恐不及
# 文件内容:
# 　　鹿鼎记
# 　　第一回      纵横钩党清流祸 峭茜风期月旦评
# 　　北风如刀，满地冰霜。
# 　　江南近海滨的一条大路上，一队清兵手执刀枪，押着七辆囚车，冲风冒寒，向北而行。
# 　　前面三辆囚
# 文件标题: ['三十三剑客图', '书剑恩仇录', '侠客行', '倚天屠龙记', '天龙八部', '射雕英雄传', '白马啸西风', '碧血剑', '神雕侠侣', '笑傲江湖', '越女剑', '连城诀', '雪山飞狐', '飞狐外传', '鸳鸯刀', '鹿鼎记']

# %%
indices = [0, 6, 10,12, 14]  # 想要提取的索引位置

novels1 = [contents[i] for i in indices]

# %%
import re
from typing import List

def split_into_paragraphs(text: str, min_length: int = 300, max_length: int = 500) -> List[str]:
    """
    将文本分割成300-500字的段落，尽量保持段落完整性
    """
    paragraphs = []
    # 首先按自然段落分割
    natural_paras = re.split(r'\n+', text.strip())
    
    current_para = ""
    for para in natural_paras:
        para = para.strip()
        if not para:
            continue
            
        # 如果当前段落加上新段落不超过最大长度，就合并
        if len(current_para) + len(para) <= max_length:
            current_para += "\n" + para if current_para else para
        else:
            # 如果当前段落已经达到最小长度，就作为一个训练样本
            if len(current_para) >= min_length:
                paragraphs.append(current_para)
                current_para = para
            else:
                # 否则继续累积
                current_para += "\n" + para
    
    # 添加最后一个段落
    if len(current_para) >= min_length:
        paragraphs.append(current_para)
    
    return paragraphs

# 示例使用
# novel_texts = [...]  # 包含所有金庸小说文本的列表
# all_paragraphs = []
# for text in novel_texts:
#     all_paragraphs.extend(split_into_paragraphs(text))

# %%
from gensim.models import FastText
import jieba

def train_fasttext_model(paragraphs: List[str], model_path: str = "fasttext_jinyong.model"):
    """
    训练FastText词向量模型
    """
    # 分词处理
    sentences = []
    for para in paragraphs:
        words = list(jieba.cut(para))
        sentences.append(words)
    
    # 训练FastText模型
    model = FastText(vector_size=300, window=5, min_count=3, workers=4)
    model.build_vocab(sentences)
    model.train(sentences, total_examples=model.corpus_count, epochs=10)
    
    # 保存模型
    model.save(model_path)
    return model

# 示例使用
# fasttext_model = train_fasttext_model(all_paragraphs)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding, Dropout
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
import numpy as np

class TextGenerator:
    def __init__(self, fasttext_model, seq_length=20):
        self.fasttext_model = fasttext_model
        self.seq_length = seq_length
        self.word_index = {word: i for i, word in enumerate(fasttext_model.wv.index_to_key)}
        self.index_word = {i: word for i, word in enumerate(fasttext_model.wv.index_to_key)}
        self.vocab_size = len(self.word_index)
        self.embedding_matrix = fasttext_model.wv.vectors
        self.model = self._build_model()
    
    def _build_model(self):
        model = Sequential([
            Embedding(input_dim=self.vocab_size,
                      output_dim=300,
                      weights=[self.embedding_matrix],
                      input_length=self.seq_length,
                      trainable=False),
            LSTM(256, return_sequences=True),
            Dropout(0.2),
            LSTM(256),
            Dropout(0.2),
            Dense(self.vocab_size, activation='softmax')
        ])
        
        model.compile(loss='categorical_crossentropy', optimizer='adam')
        return model
    
    def prepare_data(self, paragraphs):
        X, y = [], []
        
        for para in paragraphs:
            words = list(jieba.cut(para))
            for i in range(len(words) - self.seq_length):
                seq = words[i:i + self.seq_length]
                next_word = words[i + self.seq_length]
                
                # 转换为索引
                seq_idx = [self.word_index.get(word, 0) for word in seq]
                next_idx = self.word_index.get(next_word, 0)
                
                X.append(seq_idx)
                y.append(next_idx)
        
        X = pad_sequences(X, maxlen=self.seq_length)
        y = to_categorical(y, num_classes=self.vocab_size)
        
        return X, y
    
    def train(self, X, y, epochs=20, batch_size=128):
        self.model.fit(X, y, epochs=epochs, batch_size=batch_size)
    
    def generate_text(self, seed_text, num_words=100, temperature=1.0):
        generated = []
        input_seq = seed_text
        
        for _ in range(num_words):
            # 分词并获取最后seq_length个词
            words = list(jieba.cut(input_seq))
            if len(words) > self.seq_length:
                words = words[-self.seq_length:]
            elif len(words) < self.seq_length:
                # 填充
                words = [''] * (self.seq_length - len(words)) + words
            
            # 转换为索引
            seq_idx = [self.word_index.get(word, 0) for word in words]
            seq_idx = pad_sequences([seq_idx], maxlen=self.seq_length)
            
            # 预测下一个词
            preds = self.model.predict(seq_idx, verbose=0)[0]
            
            # 应用温度参数
            preds = np.log(preds) / temperature
            exp_preds = np.exp(preds)
            preds = exp_preds / np.sum(exp_preds)
            
            # 采样
            next_idx = np.random.choice(range(self.vocab_size), p=preds)
            next_word = self.index_word.get(next_idx, '')
            
            generated.append(next_word)
            input_seq += next_word
        
        return ''.join(generated)

# %%
novel_texts = novels1
all_paragraphs = []
for text in novel_texts:
    all_paragraphs.extend(split_into_paragraphs(text))

# %%
class StreamingTextGenerator:
    def __init__(self, fasttext_model, seq_length=10, max_vocab_size=5000):
        self.fasttext_model = fasttext_model
        self.seq_length = seq_length
        self.max_vocab_size = max_vocab_size
        self._build_vocab()
        self.model = self._build_model()
    
    def _build_vocab(self):
        """构建限定大小的词汇表"""
        # 按词频排序取前max_vocab_size个词
        vocab_items = sorted(self.fasttext_model.wv.key_to_index.items(), 
                           key=lambda x: x[1])[:self.max_vocab_size]
        self.word_index = {word: i+1 for i, (word, _) in enumerate(vocab_items)}  # 0保留给未知词
        self.index_word = {i+1: word for i, (word, _) in enumerate(vocab_items)}
        self.vocab_size = len(self.word_index) + 1  # 包括未知词
        self.embedding_dim = self.fasttext_model.wv.vector_size
        
        # 构建嵌入矩阵 (索引0是全零的未知词向量)
        self.embedding_matrix = np.zeros((self.vocab_size, self.embedding_dim))
        for word, i in self.word_index.items():
            self.embedding_matrix[i] = self.fasttext_model.wv[word]
    
    def _build_model(self):
        """构建LSTM模型"""
        model = Sequential([
            Embedding(input_dim=self.vocab_size,
                    output_dim=self.embedding_dim,
                    weights=[self.embedding_matrix],
                    input_length=self.seq_length,
                    trainable=False,
                    mask_zero=True),
            LSTM(64, return_sequences=True),
            Dropout(0.2),
            LSTM(64),
            Dropout(0.2),
            Dense(self.vocab_size, activation='softmax')
        ])
        model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')
        return model
    
    def data_generator(self, paragraphs, batch_size=32):
        """生成训练批数据的生成器"""
        while True:
            for para in paragraphs:
                words = list(jieba.cut(para))
                X = []
                y = []
                
                for i in range(len(words) - self.seq_length):
                    seq = words[i:i + self.seq_length]
                    next_word = words[i + self.seq_length]
                    
                    seq_idx = [self.word_index.get(word, 0) for word in seq]
                    next_idx = self.word_index.get(next_word, 0)
                    
                    X.append(seq_idx)
                    y.append(next_idx)
                    
                    if len(X) == batch_size:
                        X_padded = pad_sequences(X, maxlen=self.seq_length)
                        yield X_padded, np.array(y)
                        X, y = [], []
            
            # 处理剩余的不足一个batch的数据
            if X:
                X_padded = pad_sequences(X, maxlen=self.seq_length)
                yield X_padded, np.array(y)
    
    def generate_text(self, seed_text, num_words=100, temperature=0.7):
        """改进版生成方法：强制保持开头一致性"""
        generated = list(jieba.cut(seed_text))  # 将种子文本分词并作为初始输出
        input_seq = seed_text
        
        for _ in range(num_words):
            # 始终从原始输入开始构建序列
            context = list(jieba.cut(input_seq))[-self.seq_length:]
            if len(context) < self.seq_length:
                context = [''] * (self.seq_length - len(context)) + context
            
            seq_idx = [self.word_index.get(word, 0) for word in context]
            seq_idx = pad_sequences([seq_idx], maxlen=self.seq_length)
            
            preds = self.model.predict(seq_idx, verbose=0)[0]
            preds = np.log(preds) / temperature
            exp_preds = np.exp(preds)
            preds = exp_preds / np.sum(exp_preds)
            
            next_idx = np.random.choice(range(self.vocab_size), p=preds)
            next_word = self.index_word.get(next_idx, '')
            
            generated.append(next_word)
            input_seq += next_word  # 逐渐扩展输入序列
        
        # 确保开头与种子文本完全一致
        return seed_text + ''.join(generated[len(list(jieba.cut(seed_text))):])

# %%
def train_in_batches(generator, paragraphs, epochs=1, batch_size=16, steps_per_epoch=1000):
    # 计算每个epoch的实际步数
    total_samples = sum(len(list(jieba.cut(p))) - generator.seq_length for p in paragraphs)
    steps_per_epoch = min(steps_per_epoch, total_samples // batch_size)
    
    # 创建数据生成器
    train_gen = generator.data_generator(paragraphs, batch_size=batch_size)
    
    # 分段训练
    for epoch in range(epochs):
        print(f"Epoch {epoch+1}/{epochs}")
        history = generator.model.fit(
            train_gen,
            steps_per_epoch=steps_per_epoch,
            epochs=1,
            verbose=1
        )
        
        # 每epoch保存检查点
        generator.model.save(f"jinyong_generator_epoch{epoch+1}.h5")
        
    return history

# %%
def optimized_main():
    # 1. 加载数据（分批处理）
    novel_texts = [...]  # 您的金庸小说文本列表
    
    # 2. 训练FastText模型（小窗口减少内存）
    print("Training FastText model...")
    sentences = []
    for text in novel_texts[:10]:  # 先用部分数据训练词向量
        sentences.extend([list(jieba.cut(p)) for p in split_into_paragraphs(text)[:50]])
    
    fasttext_model = FastText(vector_size=100, window=3, min_count=5, workers=4)  # 减小参数
    fasttext_model.build_vocab(sentences)
    fasttext_model.train(sentences, total_examples=len(sentences), epochs=5)
    
    # 3. 初始化生成器（小词汇量）
    print("Initializing generator...")
    generator = StreamingTextGenerator(fasttext_model, seq_length=8, max_vocab_size=3000)
    
    # 4. 分批加载和训练数据
    print("Starting training...")
    for i, text in enumerate(novel_texts):
        print(f"Processing novel {i+1}/{len(novel_texts)}")
        paragraphs = split_into_paragraphs(text)[:100]  # 限制每部小说的段落数
        
        # 训练当前小说的数据
        train_in_batches(
            generator, 
            paragraphs, 
            epochs=1, 
            batch_size=16, 
            steps_per_epoch=500
        )
    
    # 5. 最终模型保存
    generator.model.save("jinyong_final_generator.h5")
    
    # 6. 测试生成
    seed_text = "只见那"
    generated = generator.generate_text(seed_text, num_words=200)
    print(f"生成结果:\n{generated}")

def generate_text(self, seed_text, num_words=100, temperature=1.0):
    generated = []
    input_seq = seed_text
    
    for _ in range(num_words):
        words = list(jieba.cut(input_seq))[-self.seq_length:]
        if len(words) < self.seq_length:
            words = [''] * (self.seq_length - len(words)) + words
        
        seq_idx = [self.word_index.get(word, 0) for word in words]
        seq_idx = pad_sequences([seq_idx], maxlen=self.seq_length)
        
        preds = self.model.predict(seq_idx, verbose=0)[0]
        preds = np.log(preds) / temperature
        exp_preds = np.exp(preds)
        preds = exp_preds / np.sum(exp_preds)
        
        next_idx = np.random.choice(range(self.vocab_size), p=preds)
        next_word = self.index_word.get(next_idx, '')
        
        generated.append(next_word)
        input_seq += next_word
    
    return ''.join(generated)

# %%
import matplotlib.pyplot as plt
def plot_training_loss(loss_values):
    """绘制训练loss曲线"""
    plt.figure(figsize=(10, 6))
    plt.plot(loss_values, label='Training Loss')
    plt.title('Training Loss Over Batches')
    plt.xlabel('Batch Number')
    plt.ylabel('Loss')
    plt.legend()
    
    # 平滑曲线（可选）
    window_size = max(1, len(loss_values) // 100)  # 动态窗口大小
    smooth_loss = np.convolve(loss_values, np.ones(window_size)/window_size, mode='valid')
    plt.plot(smooth_loss, label=f'Smoothed (window={window_size})', alpha=0.7)
    
    plt.grid(True)
    plt.savefig('training_loss.png')  # 保存图像
    plt.show()

# %%
def generate_text(self, seed_text, num_words=100, temperature=1.0):
    generated = []
    input_seq = seed_text
    
    for _ in range(num_words):
        words = list(jieba.cut(input_seq))[-self.seq_length:]
        if len(words) < self.seq_length:
            words = [''] * (self.seq_length - len(words)) + words
        
        seq_idx = [self.word_index.get(word, 0) for word in words]
        seq_idx = pad_sequences([seq_idx], maxlen=self.seq_length)
        
        preds = self.model.predict(seq_idx, verbose=0)[0]
        preds = np.log(preds) / temperature
        exp_preds = np.exp(preds)
        preds = exp_preds / np.sum(exp_preds)
        
        next_idx = np.random.choice(range(self.vocab_size), p=preds)
        next_word = self.index_word.get(next_idx, '')
        
        generated.append(next_word)
        input_seq += next_word
    
    return ''.join(generated)

# %%
alltext=[]
def test_generation(generator):
    """测试文本生成"""
    seed_texts = [
        "曾小贤吃过了烤鱼，",
        "胡霏回眸一笑，",
        "陆展堂大喝一声，",
        "林瑛宛转身，",
        "吕峰把碗筷一摔，"
    ]
    
    for seed in seed_texts:
        print(f"\n种子文本: '{seed}'")
        generated = generator.generate_text(seed, num_words=150)
        print("生成文本:")
        alltext.append(generated)
        print("-" * 50)
        print(generated)
        print("-" * 50)

# %%
print("步骤1/4: 训练FastText词向量...")
sentences = []
for text in novel_texts[:]:  # 先用前3部小说训练词向量
    for para in split_into_paragraphs(text)[:80]:  # 每部取前50段
        sentences.append(list(jieba.cut(para)))
    
fasttext_model = FastText(
    vector_size=100,  # 减小维度
    window=5,
    min_count=5,
    workers=4
)
fasttext_model.build_vocab(sentences)
fasttext_model.train(sentences, total_examples=len(sentences), epochs=800)
# Out:
# 步骤1/4: 训练FastText词向量...
# (52207320, 100697600)

# %%
print("步骤2/4: 初始化文本生成器...")
generator = StreamingTextGenerator(
    fasttext_model,
    seq_length=15,          # 较短的序列长度
    max_vocab_size=4000    # 较小的词汇表
)
# Out:
# 步骤2/4: 初始化文本生成器...

# %%
print("步骤3/4: 开始分批训练...")
for i, text in enumerate(novel_texts):
    print(f"正在处理第 {i+1}/{len(novel_texts)} 部小说...")
    paragraphs = split_into_paragraphs(text)[:100]  # 限制每部小说的段落数
        
        # 训练当前小说的数据
    train_in_batches(
        generator=generator,
        paragraphs=paragraphs,
        epochs=100,            # 每部小说训练1轮
        batch_size=16,        # 小批量
        steps_per_epoch=300   # 每轮200步
    )
# Out:
# 步骤3/4: 开始分批训练...
# 正在处理第 1/5 部小说...
# Epoch 1/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 5.8036
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 2/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.6001
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 3/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 5.0164
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 4/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.2778
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 5/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 5.1984
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 6/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.6536
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 7/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.8761
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 8/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.9109
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 9/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 4.4304
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 10/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.0699
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 11/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.7305
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 12/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.0201
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 13/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.7699
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 14/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.2835
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 15/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 4.6373
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 16/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 4.5580
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 17/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 4.4943
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 18/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.1354
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 19/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 4.6465
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 20/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.0954
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 21/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.3481
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 22/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.3999
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 23/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.2288
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 24/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 4.4624
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 25/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.3530
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 26/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.1777
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 27/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.6377
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 28/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.3212
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 29/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.5700
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 30/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.4104
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 31/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.9358
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 32/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 4.3369
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 33/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.4176
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 34/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.1540
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 35/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.8907
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 36/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 4.3333
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 37/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.5381
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 38/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.8807
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 39/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 4.0021
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 40/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.1089
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 41/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.0270
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 42/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 4.1686
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 43/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.7003
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 44/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8868
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 45/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9320
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 46/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9616
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 47/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.1384
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 48/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.9994
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 49/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.0726
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 50/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.0452
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 51/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8177
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 52/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.4385
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 53/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.0267
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 54/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.5070
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 55/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.0218
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 56/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.7364
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 57/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.0761
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 58/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.9935
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 59/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 3.7718
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 60/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.7478
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 61/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.9306
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 62/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.4466
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 63/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.7370
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 64/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8112
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 65/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.7066
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 66/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8832
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 67/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8751
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 68/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.6173
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 69/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.4141
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 70/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.7700
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 71/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.3342
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 72/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.0375
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 73/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.6767
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 74/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.7727
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 75/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8714
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 76/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.5636
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 77/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.4140
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 78/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.7593
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 79/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.3163
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 80/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8924
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 81/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.6174
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 82/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.8401
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 83/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.6699
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 84/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.7335
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 85/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.4455
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 86/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.7599
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 87/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.3442
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 88/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.6369
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 89/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.6812
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 90/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.6033
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 91/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.7370
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 92/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.6369
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 93/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.5180
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 94/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.0481
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 95/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.6500
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 96/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.1134
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 97/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.7637
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 98/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.3820
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 99/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.6700
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 100/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.7112
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 正在处理第 2/5 部小说...
# Epoch 1/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 7.0577
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 2/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 5.9466
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 3/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 5.8919
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 4/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 5.4185
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 5/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 5.4002
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 6/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 5.0413
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 7/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 4.9464
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 8/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.7183
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 9/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 5.0760
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 10/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 5.0286
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 11/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.7293
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 12/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.8568
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 13/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.6333
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 14/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.5596
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 15/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.6128
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 16/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.7765
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 17/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 4.6478
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 18/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.6945
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 19/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.4100
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 20/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.5543
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 21/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.3991
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 22/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.6515
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 23/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.6263
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 24/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.3992
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 25/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.4843
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 26/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.2935
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 27/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.3542
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 28/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.4146
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 29/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 4.4169
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 30/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.3206
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 31/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 4.3828
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 32/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.2162
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 33/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 4.2271
# ...
# Epoch 57/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.6806
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 58/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.4552
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 59/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.8685
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 60/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.7503
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 61/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.7230
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 62/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.6702
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 63/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.5442
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 64/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.7151
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 65/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.6870
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 66/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.6916
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 67/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.4575
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 68/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.5793
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 69/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.6968
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 70/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.6067
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 71/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.5718
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 72/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.3773
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 73/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.7201
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 74/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.6866
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 75/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.5893
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 76/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.6446
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 77/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.3612
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 78/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.5918
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 79/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.5479
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 80/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.5477
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 81/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.3809
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 82/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.4305
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 83/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.5139
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 84/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.5429
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 85/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 3.4973
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 86/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.3132
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 87/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 3.3111
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 88/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 3.5108
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 89/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 3.4927
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 90/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 3.2930
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 91/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.3489
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 92/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.4354
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 93/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.4136
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 94/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 3.4753
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 95/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.3390
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 96/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 3.2190
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 97/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.4088
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 98/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.3827
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 99/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.3803
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 100/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.2812
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
print("步骤4/4: 保存模型...")
generator.model.save("jinyong_final_model.h5")
print("模型训练完成并已保存!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 步骤4/4: 保存模型...
# 模型训练完成并已保存!

# %%
test_generation(generator)
# Out:
# 种子文本: '曾小贤吃过了烤鱼，'
# 生成文本:
# --------------------------------------------------
# 曾小贤吃过了烤鱼，但说，却是
# ，。」
# 周威信一见，定
# 将他，在地下，，
# 了，那。我不杀他皇上我，你便了。」袁冠南道：「，连你了
# ，了，！」忙，一惊，伸手向那凶徒的
# ，而至。周威信手指一
# ，得。逍遥子道：「两位
# ，你要好心，我给我
# --------------------------------------------------
#
# 种子文本: '胡霏回眸一笑，'
# 生成文本:
# --------------------------------------------------
# 胡霏回眸一笑，便如
# ，。
# 萧半和奔出，但伸手周威信将他
# 叫道：「贼小子，你
# ，你江湖上人称江湖人称『鸳鸯刀』？」盖一鸣道：「，你就抢给你？」林玉龙道：「我知道吧，把说的，解开，当真这麽？」盖一鸣道：「安
# ，便问了。」盖一鸣道：「大哥料事如神，言之有理。」那少女道：「我不用，你给你
# --------------------------------------------------
#
# 种子文本: '陆展堂大喝一声，'
# 生成文本:
# --------------------------------------------------
# 陆展堂大喝一声，向这对宝刀却夫人，眼见四位将皇帝。」众是盖一鸣道：「不错，你到底这
# ，不睡？」袁萧二人胸口，眼见林玉龙，也他。四人伸手道：「大人……」只听他仍是的人，瞧
# 了，那少女身前，忙抱去。
# 盖一鸣道：「这麽容易，原来是你不知，不能不是他，在下的夫妻刀法。」花剑影
# --------------------------------------------------
#
# 种子文本: '林瑛宛转身，'
# 生成文本:
# --------------------------------------------------
# 林瑛宛转身，
# 是，可还不能也，。」说著，说道：「人间
# 姑娘，你还能给我，好朋友们？」常长风道：「打架，我来我伤了你夫妻，假。」林玉龙道：「，
# 让你们什麽？」盖一鸣道：「我跟我们老人家
# 一口。」说著他，伸手。卓天雄卓天雄又
# ，骂道：「贼婆娘，。」那书生道：
# --------------------------------------------------
#
# 种子文本: '吕峰把碗筷一摔，'
# 生成文本:
# --------------------------------------------------
# 吕峰把碗筷一摔，，，原来他，，嘴里，，
# 的，。
# 那少女道：「你这麽？」萧中慧道：「大哥料事如神，言之有理。」
# 卓天雄纵声好笑，道：「萧大侠是谁
# ？」便便如，在人影上头顶动，已给逍遥子的一声。
# 萧中慧以
# ，。卓天雄，飞出，自，，，侍卫，刀。
# 那
# --------------------------------------------------

# %%
import jieba
from nltk.translate.bleu_score import sentence_bleu
from collections import defaultdict

# %%
def calculate_dist1(text):
    # 分词
    words = jieba.lcut(text)
    # 计算唯一词汇数量
    unique_words = len(set(words))
    # 计算 Dist-1
    if len(words) == 0:
        return 0
    return unique_words / len(words)

# %%
def calculate_self_bleu(text, n=4):
    # 分句
    sentences = text.split('。')  # 根据中文句号分句
    sentences = [s.strip() for s in sentences if s.strip() != '']
    
    # 如果只有一个句子，返回 1（BLEU无法计算）
    if len(sentences) == 1:
        return 1.0
    
    # 将所有句子作为参考
    references = [[word for word in jieba.lcut(s)] for s in sentences]
    
    # 计算每个句子与所有其他句子的平均 BLEU 值
    bleu_scores = []
    for i in range(len(sentences)):
        hypothesis = references[i]
        ref = references[:i] + references[i+1:]  # 排除当前句子作为参考
        if not ref:
            bleu_scores.append(0.0)
            continue
        
        # 计算当前句子与所有其他句子的平均 BLEU 值
        total_score = 0.0
        for j in range(len(ref)):
            # BLEU 计算需要参考句子列表
            total_score += sentence_bleu([ref[j]], hypothesis, weights=(1/n,)*n)
        avg_score = total_score / len(ref)
        bleu_scores.append(avg_score)
    
    # 取所有句子的平均值
    return sum(bleu_scores) / len(bleu_scores)

# %%
def evaluate_text_list(text_list):
    results = []
    for text in text_list:
        # 计算 Dist-1
        dist1 = calculate_dist1(text)
        
        # 计算 Self-BLEU
        self_bleu = calculate_self_bleu(text)
        
        results.append({
            'text': text,
            'Dist-1': dist1,
            'Self-BLEU': self_bleu
        })
    return results

# 示例使用
text_list = alltext

results = evaluate_text_list(text_list)

for res in results:
    print(f"文本：{res['text']}")
    print(f"Dist-1：{res['Dist-1']:.4f}")
    print(f"Self-BLEU：{res['Self-BLEU']:.4f}")
    print("-----------------------------")
# Out:
# 文本：曾小贤吃过了烤鱼，但说，却是
# ，。」
# 周威信一见，定
# 将他，在地下，，
# 了，那。我不杀他皇上我，你便了。」袁冠南道：「，连你了
# ，了，！」忙，一惊，伸手向那凶徒的
# ，而至。周威信手指一
# ，得。逍遥子道：「两位
# ，你要好心，我给我
# Dist-1：0.5161
# Self-BLEU：0.0000
# -----------------------------
# 文本：胡霏回眸一笑，便如
# ，。
# 萧半和奔出，但伸手周威信将他
# 叫道：「贼小子，你
# ，你江湖上人称江湖人称『鸳鸯刀』？」盖一鸣道：「，你就抢给你？」林玉龙道：「我知道吧，把说的，解开，当真这麽？」盖一鸣道：「安
# ，便问了。」盖一鸣道：「大哥料事如神，言之有理。」那少女道：「我不用，你给你
# Dist-1：0.5340
# Self-BLEU：0.0081
# -----------------------------
# 文本：陆展堂大喝一声，向这对宝刀却夫人，眼见四位将皇帝。」众是盖一鸣道：「不错，你到底这
# ，不睡？」袁萧二人胸口，眼见林玉龙，也他。四人伸手道：「大人……」只听他仍是的人，瞧
# 了，那少女身前，忙抱去。
# 盖一鸣道：「这麽容易，原来是你不知，不能不是他，在下的夫妻刀法。」花剑影
# Dist-1：0.6392
# Self-BLEU：0.0114
# -----------------------------
# 文本：林瑛宛转身，
# 是，可还不能也，。」说著，说道：「人间
# 姑娘，你还能给我，好朋友们？」常长风道：「打架，我来我伤了你夫妻，假。」林玉龙道：「，
# 让你们什麽？」盖一鸣道：「我跟我们老人家
# 一口。」说著他，伸手。卓天雄卓天雄又
# ，骂道：「贼婆娘，。」那书生道：
# Dist-1：0.5408
# Self-BLEU：0.0000
# -----------------------------
# 文本：吕峰把碗筷一摔，，，原来他，，嘴里，，
# 的，。
# 那少女道：「你这麽？」萧中慧道：「大哥料事如神，言之有理。」
# 卓天雄纵声好笑，道：「萧大侠是谁
# ？」便便如，在人影上头顶动，已给逍遥子的一声。
# 萧中慧以
# ，。卓天雄，飞出，自，，，侍卫，刀。
# 那
# Dist-1：0.5385
# Self-BLEU：0.0000
# -----------------------------
# d:\anaconda\envs\esrgan\Lib\site-packages\nltk\translate\bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# d:\anaconda\envs\esrgan\Lib\site-packages\nltk\translate\bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# d:\anaconda\envs\esrgan\Lib\site-packages\nltk\translate\bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %%
import jieba
import math
from collections import defaultdict

def calculate_perplexity(text):
    # 分词
    words = jieba.lcut(text)
    if len(words) == 0:
        return 0.0  # 如果文本为空，返回0
    
    # 假设我们有一个简单的bigram模型，这里使用示例数据
    # 实际应用中，模型应该基于训练数据构建
    # 这里示例中使用一个简单的频率统计
    bigram_model = defaultdict(lambda: defaultdict(int))
    total_words = 0
    
    # 示例训练数据（实际应为训练语料）
    # 这里仅作示例，真实情况下需要基于训练数据构建模型
    training_corpus = contents
    
    # 统计bigram频率
    for sentence in training_corpus:
        sentence_words = jieba.lcut(sentence)
        for i in range(len(sentence_words) - 1):
            current_word = sentence_words[i]
            next_word = sentence_words[i + 1]
            bigram_model[current_word][next_word] += 1
            total_words += 1
    
    # 计算条件概率，使用加一平滑
    perplexity = 0.0
    for i in range(len(words) - 1):
        current_word = words[i]
        next_word = words[i + 1]
        
        # 获取当前词的所有可能后续词及其频率
        current_bigram = bigram_model.get(current_word, {})
        total_bigram = sum(current_bigram.values()) + len(current_bigram)  # 加一平滑
        
        # 计算条件概率
        if total_bigram == 0:
            prob = 1.0 / (total_bigram + 1)  # 避免除零错误
        else:
            count = current_bigram.get(next_word, 0)
            prob = (count + 1) / (total_bigram + len(current_bigram))
        
        # 累加对数概率（以2为底）
        perplexity += math.log2(prob)
    
    # 计算最终的困惑度
    if len(words) - 1 == 0:
        return 0.0  # 如果只有一个词，困惑度无法计算
    perplexity = 2 ** (-perplexity / (len(words) - 1))
    
    return perplexity

def evaluate_perplexity(text_list):
    results = []
    for text in text_list:
        perplexity = calculate_perplexity(text)
        results.append({
            'text': text,
            'Perplexity': perplexity
        })
    return results

# 示例使用
text_list = alltext

perplexity_results = evaluate_perplexity(text_list)

for res in perplexity_results:
    print(f"文本：{res['text']}")
    print(f"困惑度：{res['Perplexity']:.4f}")
    print("-----------------------------")
# Out:
# 文本：曾小贤吃过了烤鱼，但说，却是
# ，。」
# 周威信一见，定
# 将他，在地下，，
# 了，那。我不杀他皇上我，你便了。」袁冠南道：「，连你了
# ，了，！」忙，一惊，伸手向那凶徒的
# ，而至。周威信手指一
# ，得。逍遥子道：「两位
# ，你要好心，我给我
# 困惑度：179.8467
# -----------------------------
# 文本：胡霏回眸一笑，便如
# ，。
# 萧半和奔出，但伸手周威信将他
# 叫道：「贼小子，你
# ，你江湖上人称江湖人称『鸳鸯刀』？」盖一鸣道：「，你就抢给你？」林玉龙道：「我知道吧，把说的，解开，当真这麽？」盖一鸣道：「安
# ，便问了。」盖一鸣道：「大哥料事如神，言之有理。」那少女道：「我不用，你给你
# 困惑度：76.2390
# -----------------------------
# 文本：陆展堂大喝一声，向这对宝刀却夫人，眼见四位将皇帝。」众是盖一鸣道：「不错，你到底这
# ，不睡？」袁萧二人胸口，眼见林玉龙，也他。四人伸手道：「大人……」只听他仍是的人，瞧
# 了，那少女身前，忙抱去。
# 盖一鸣道：「这麽容易，原来是你不知，不能不是他，在下的夫妻刀法。」花剑影
# 困惑度：121.8679
# -----------------------------
# 文本：林瑛宛转身，
# 是，可还不能也，。」说著，说道：「人间
# 姑娘，你还能给我，好朋友们？」常长风道：「打架，我来我伤了你夫妻，假。」林玉龙道：「，
# 让你们什麽？」盖一鸣道：「我跟我们老人家
# 一口。」说著他，伸手。卓天雄卓天雄又
# ，骂道：「贼婆娘，。」那书生道：
# 困惑度：101.1192
# -----------------------------
# 文本：吕峰把碗筷一摔，，，原来他，，嘴里，，
# 的，。
# 那少女道：「你这麽？」萧中慧道：「大哥料事如神，言之有理。」
# 卓天雄纵声好笑，道：「萧大侠是谁
# ？」便便如，在人影上头顶动，已给逍遥子的一声。
# 萧中慧以
# ，。卓天雄，飞出，自，，，侍卫，刀。
# 那
# 困惑度：253.8175
# -----------------------------

# %%
loss_values = [
    5.8036, 4.6001, 5.0164, 4.2778, 5.1984, 4.6536, 4.8761, 4.9109, 4.4304, 4.0699,
    4.7305, 4.0201, 4.7699, 4.2835, 4.6373, 4.5580, 4.4943, 4.1354, 4.6465, 4.0954,
    4.3481, 4.3999, 4.2288, 4.4624, 4.3530, 4.1777, 3.6377, 4.3212, 3.5700, 4.4104,
    3.9358, 4.3369, 4.4176, 4.1540, 3.8907, 4.3333, 3.5381, 3.8807, 4.0021, 4.1089,
    4.0270, 4.1686, 3.7003, 3.8868, 3.9320, 3.9616, 4.1384, 3.9994, 4.0726, 4.0452,
    3.8177, 3.4385, 4.0267, 3.5070, 4.0218, 3.7364, 4.0761, 3.9935, 3.7718, 3.7478,
    3.9306, 3.4466, 3.7370, 3.8112, 3.7066, 3.8832, 3.8751, 3.6173, 3.4141, 3.7700,
    3.3342, 4.0375, 3.6767, 3.7727, 3.8714, 3.5636, 3.4140, 3.7593, 3.3163, 3.8924,
    3.6174, 3.8401, 3.6699, 3.7335, 3.4455, 3.7599, 3.3442, 3.6369, 3.6812, 3.6033,
    3.7370, 3.6369, 3.5180, 3.0481, 3.6500, 3.1134, 3.7637, 3.3820, 3.6700, 3.7112
]

# %%
losses=loss_values
import matplotlib.pyplot as plt
lgg=len(losses)
# 损失数据
epoch = list(range(1,lgg+1))
loss = losses

# 绘制损失曲线
plt.plot(epoch, loss,color="red")
plt.title('Training Loss vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
